# %% [markdown]
# ### Project: Data Analyst - Assignment
# ### Author: Suhel Khan
# ### Code Submission Date: 13-02-2024
# ### Author's Contact Info: ksuhel80@gmail.com

# %% [markdown]
# ### Reading Csv

# %%
# importing Libraries 
import pandas as pd
import numpy as np
pd.options.display.max_rows = 4000


df_order_report = pd.read_excel('./Company X - Order Report.xlsx')
df_order_report.head()
# Out:
#    ExternOrderNo            SKU  Order Qty
# 0     2001827036  8904223818706        1.0
# 1     2001827036  8904223819093        1.0
# 2     2001827036  8904223819109        1.0
# 3     2001827036  8904223818430        1.0
# 4     2001827036  8904223819277        1.0

# %%
df_pincode_zones = pd.read_excel('./Company X - Pincode Zones.xlsx')
df_pincode_zones.head()
# Out:
#    Warehouse Pincode  Customer Pincode Zone
# 0             121003            507101    d
# 1             121003            486886    d
# 2             121003            532484    d
# 3             121003            143001    b
# 4             121003            515591    d

# %%
df_sku_master = pd.read_excel('./Company X - SKU Master.xlsx')
df_sku_master.head()
# Out:
#              SKU  Weight (g)
# 0  8904223815682         210
# 1  8904223815859         165
# 2  8904223815866         113
# 3  8904223815873          65
# 4  8904223816214         120

# %%
df_courier_invoice = pd.read_excel('./Courier Company - Invoice.xlsx')
df_courier_invoice.head()
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0  1091117222124  2001806232            1.30             121003
# 1  1091117222194  2001806273            1.00             121003
# 2  1091117222931  2001806408            2.50             121003
# 3  1091117223244  2001806458            1.00             121003
# 4  1091117229345  2001807012            0.15             121003
#
#    Customer Pincode Zone Type of Shipment  Billing Amount (Rs.)
# 0            507101    d  Forward charges                 135.0
# 1            486886    d  Forward charges                  90.2
# 2            532484    d  Forward charges                 224.6
# 3            143001    b  Forward charges                  61.3
# 4            515591    d  Forward charges                  45.4

# %%
df_courier_rates = pd.read_excel('./Courier Company - Rates.xlsx')
df_courier_rates.head()
# Out:
#   Zone  Weight Slabs  Forward Fixed Charge  \
# 0    A          0.50                  29.5
# 1    B          1.00                  33.0
# 2    C          1.25                  40.1
# 3    D          1.50                  45.4
# 4    E          2.00                  56.6
#
#    Forward Additional Weight Slab Charge  RTO Fixed Charge  \
# 0                                   23.6              13.6
# 1                                   28.3              20.5
# 2                                   38.9              31.9
# 3                                   44.8              41.3
# 4                                   55.5              50.7
#
#    RTO Additional Weight Slab Charge
# 0                               23.6
# 1                               28.3
# 2                               38.9
# 3                               44.8
# 4                               55.5

# %%
df_order_report.dtypes
# Out:
# ExternOrderNo      int64
# SKU               object
# Order Qty        float64
# dtype: object

# %% [markdown]
# ## Adding weight column by using left join

# %%
df_order_report = pd.merge(df_order_report, df_sku_master[['SKU', 'Weight (g)']], on='SKU', how='left')

# %%
df_order_report.head()
# Out:
#    ExternOrderNo            SKU  Order Qty  Weight (g)
# 0     2001827036  8904223818706        1.0         127
# 1     2001827036  8904223819093        1.0         150
# 2     2001827036  8904223819109        1.0         100
# 3     2001827036  8904223818430        1.0         165
# 4     2001827036  8904223819277        1.0         350

# %% [markdown]
# ### Calculating total weight

# %%
df_order_report['Total Weight'] = (df_order_report['Order Qty'] * df_order_report['Weight (g)'])/1000
df_order_report.head(20)
# Out:
#     ExternOrderNo            SKU  Order Qty  Weight (g)  Total Weight
# 0      2001827036  8904223818706        1.0         127         0.127
# 1      2001827036  8904223819093        1.0         150         0.150
# 2      2001827036  8904223819109        1.0         100         0.100
# 3      2001827036  8904223818430        1.0         165         0.165
# 4      2001827036  8904223819277        1.0         350         0.350
# 5      2001827036  GIFTBOX202002        1.0         500         0.500
# 6      2001827036  GIFTBOX202002        1.0         500         0.500
# 7      2001827036  8904223818638        2.0         137         0.274
# 8      2001827036     SACHETS001        1.0          10         0.010
# 9      2001825261  8904223819024        4.0         112         0.448
# 10     2001825261  8904223819291        4.0         112         0.448
# 11     2001825261  8904223818638        3.0         137         0.411
# 12     2001825261  8904223818669        1.0         240         0.240
# 13     2001825261     SACHETS001        1.0          10         0.010
# 14     2001823564  8904223819291        2.0         112         0.224
# 15     2001823564  8904223819031        2.0         112         0.224
# 16     2001823564  8904223819024        2.0         112         0.224
# 17     2001822466  8904223819468        2.0         240         0.480
# 18     2001822466  8904223819291        8.0         112         0.896
# 19     2001821995  8904223819130        1.0         350         0.350

# %% [markdown]
# ### Creating a new dataset by grouping the data with Order No

# %%
grouped_data = df_order_report.groupby('ExternOrderNo')['Total Weight'].sum().reset_index()
grouped_data.columns = ['Order ID', 'Weight X Company']

# %% [markdown]
# ### Creating a new dataset with left join on invoice dataset with weight

# %%
merged_dataset = pd.merge(df_courier_invoice, grouped_data[['Order ID', 'Weight X Company']], on='Order ID', how='left')

# %%
merged_dataset.head(10)
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0  1091117222124  2001806232            1.30             121003
# 1  1091117222194  2001806273            1.00             121003
# 2  1091117222931  2001806408            2.50             121003
# 3  1091117223244  2001806458            1.00             121003
# 4  1091117229345  2001807012            0.15             121003
# 5  1091117229555  2001806686            0.15             121003
# 6  1091117229776  2001806885            1.00             121003
# 7  1091117323112  2001807058            1.15             121003
# 8  1091117323812  2001807186            0.50             121003
# 9  1091117324206  2001807290            0.50             121003
#
#    Customer Pincode Zone Type of Shipment  Billing Amount (Rs.)  \
# 0            507101    d  Forward charges                 135.0
# 1            486886    d  Forward charges                  90.2
# 2            532484    d  Forward charges                 224.6
# 3            143001    b  Forward charges                  61.3
# 4            515591    d  Forward charges                  45.4
# 5            326502    d  Forward charges                  45.4
# 6            208019    b  Forward charges                  61.3
# 7            140301    b  Forward charges                  89.6
# 8            396001    d  Forward charges                  45.4
# 9            711106    d  Forward charges                  45.4
#
#    Weight X Company
# 0             1.302
# 1             0.615
# 2             2.265
# 3             0.700
# 4             0.240
# 5             0.240
# 6             0.840
# 7             1.168
# 8             0.500
# 9             0.500

# %% [markdown]
# ### Renaming Columns

# %%
df_pincode_zones.rename(columns={'Zone':'Zone X'},inplace=True)

# %%
df_pincode_zones.head()
# Out:
#    Warehouse Pincode  Customer Pincode Zone X
# 0             121003            507101      d
# 1             121003            486886      d
# 2             121003            532484      d
# 3             121003            143001      b
# 4             121003            515591      d

# %%
merged_dataset = pd.merge(merged_dataset, df_pincode_zones[['Customer Pincode', 'Zone X']], on='Customer Pincode', how='left')

# %%
merged_dataset.rename(columns={'Zone':'Zone Courier','Zone X':'Zone' },inplace=True)
merged_dataset.head(10)
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0  1091117222124  2001806232            1.30             121003
# 1  1091117222194  2001806273            1.00             121003
# 2  1091117222931  2001806408            2.50             121003
# 3  1091117223244  2001806458            1.00             121003
# 4  1091117229345  2001807012            0.15             121003
# 5  1091117229555  2001806686            0.15             121003
# 6  1091117229776  2001806885            1.00             121003
# 7  1091117323112  2001807058            1.15             121003
# 8  1091117323112  2001807058            1.15             121003
# 9  1091117323812  2001807186            0.50             121003
#
#    Customer Pincode Zone Courier Type of Shipment  Billing Amount (Rs.)  \
# 0            507101            d  Forward charges                 135.0
# 1            486886            d  Forward charges                  90.2
# 2            532484            d  Forward charges                 224.6
# 3            143001            b  Forward charges                  61.3
# 4            515591            d  Forward charges                  45.4
# 5            326502            d  Forward charges                  45.4
# 6            208019            b  Forward charges                  61.3
# 7            140301            b  Forward charges                  89.6
# 8            140301            b  Forward charges                  89.6
# 9            396001            d  Forward charges                  45.4
#
#    Weight X Company Zone
# 0             1.302    d
# 1             0.615    d
# 2             2.265    d
# 3             0.700    b
# 4             0.240    d
# 5             0.240    d
# 6             0.840    b
# 7             1.168    b
# 8             1.168    b
# 9             0.500    d

# %%
df_courier_rates.columns
# Out:
# Index(['Zone', 'Weight Slabs', 'Forward Fixed Charge',
#        'Forward Additional Weight Slab Charge', 'RTO Fixed Charge',
#        'RTO Additional Weight Slab Charge'],
#       dtype='object')

# %%
df_courier_rates['Zone'] = df_courier_rates['Zone'].str.lower()
df_courier_rates.head()
# Out:
#   Zone  Weight Slabs  Forward Fixed Charge  \
# 0    a          0.50                  29.5
# 1    b          1.00                  33.0
# 2    c          1.25                  40.1
# 3    d          1.50                  45.4
# 4    e          2.00                  56.6
#
#    Forward Additional Weight Slab Charge  RTO Fixed Charge  \
# 0                                   23.6              13.6
# 1                                   28.3              20.5
# 2                                   38.9              31.9
# 3                                   44.8              41.3
# 4                                   55.5              50.7
#
#    RTO Additional Weight Slab Charge
# 0                               23.6
# 1                               28.3
# 2                               38.9
# 3                               44.8
# 4                               55.5

# %% [markdown]
# ### Created a new dataset with left join on courier rates dataset

# %%
merged_dataset_new = pd.merge(merged_dataset, df_courier_rates[['Zone', 'Weight Slabs','Forward Fixed Charge','Forward Additional Weight Slab Charge', 'RTO Fixed Charge',
       'RTO Additional Weight Slab Charge']], on='Zone', how='left')
merged_dataset_new.head(10)
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0  1091117222124  2001806232            1.30             121003
# 1  1091117222194  2001806273            1.00             121003
# 2  1091117222931  2001806408            2.50             121003
# 3  1091117223244  2001806458            1.00             121003
# 4  1091117229345  2001807012            0.15             121003
# 5  1091117229555  2001806686            0.15             121003
# 6  1091117229776  2001806885            1.00             121003
# 7  1091117323112  2001807058            1.15             121003
# 8  1091117323112  2001807058            1.15             121003
# 9  1091117323812  2001807186            0.50             121003
#
#    Customer Pincode Zone Courier Type of Shipment  Billing Amount (Rs.)  \
# 0            507101            d  Forward charges                 135.0
# 1            486886            d  Forward charges                  90.2
# 2            532484            d  Forward charges                 224.6
# 3            143001            b  Forward charges                  61.3
# 4            515591            d  Forward charges                  45.4
# 5            326502            d  Forward charges                  45.4
# 6            208019            b  Forward charges                  61.3
# 7            140301            b  Forward charges                  89.6
# 8            140301            b  Forward charges                  89.6
# 9            396001            d  Forward charges                  45.4
#
#    Weight X Company Zone  Weight Slabs  Forward Fixed Charge  \
# 0             1.302    d           1.5                  45.4
# 1             0.615    d           1.5                  45.4
# 2             2.265    d           1.5                  45.4
# 3             0.700    b           1.0                  33.0
# 4             0.240    d           1.5                  45.4
# 5             0.240    d           1.5                  45.4
# 6             0.840    b           1.0                  33.0
# 7             1.168    b           1.0                  33.0
# 8             1.168    b           1.0                  33.0
# 9             0.500    d           1.5                  45.4
#
#    Forward Additional Weight Slab Charge  RTO Fixed Charge  \
# 0                                   44.8              41.3
# 1                                   44.8              41.3
# 2                                   44.8              41.3
# 3                                   28.3              20.5
# 4                                   44.8              41.3
# 5                                   44.8              41.3
# 6                                   28.3              20.5
# 7                                   28.3              20.5
# 8                                   28.3              20.5
# 9                                   44.8              41.3
#
#    RTO Additional Weight Slab Charge
# 0                               44.8
# 1                               44.8
# 2                               44.8
# 3                               28.3
# 4                               44.8
# 5                               44.8
# 6                               28.3
# 7                               28.3
# 8                               28.3
# 9                               44.8

# %%
merged_dataset_new.dtypes
# Out:
# AWB Code                                   int64
# Order ID                                   int64
# Charged Weight                           float64
# Warehouse Pincode                          int64
# Customer Pincode                           int64
# Zone Courier                              object
# Type of Shipment                          object
# Billing Amount (Rs.)                     float64
# Weight X Company                         float64
# Zone                                      object
# Weight Slabs                             float64
# Forward Fixed Charge                     float64
# Forward Additional Weight Slab Charge    float64
# RTO Fixed Charge                         float64
# RTO Additional Weight Slab Charge        float64
# dtype: object

# %% [markdown]
# ### calculated No of slabs

# %%
merged_dataset_new['No Of Slabs'] = np.ceil(merged_dataset_new['Weight X Company']/merged_dataset_new['Weight Slabs'])
merged_dataset_new.head()
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0  1091117222124  2001806232            1.30             121003
# 1  1091117222194  2001806273            1.00             121003
# 2  1091117222931  2001806408            2.50             121003
# 3  1091117223244  2001806458            1.00             121003
# 4  1091117229345  2001807012            0.15             121003
#
#    Customer Pincode Zone Courier Type of Shipment  Billing Amount (Rs.)  \
# 0            507101            d  Forward charges                 135.0
# 1            486886            d  Forward charges                  90.2
# 2            532484            d  Forward charges                 224.6
# 3            143001            b  Forward charges                  61.3
# 4            515591            d  Forward charges                  45.4
#
#    Weight X Company Zone  Weight Slabs  Forward Fixed Charge  \
# 0             1.302    d           1.5                  45.4
# 1             0.615    d           1.5                  45.4
# 2             2.265    d           1.5                  45.4
# 3             0.700    b           1.0                  33.0
# 4             0.240    d           1.5                  45.4
#
#    Forward Additional Weight Slab Charge  RTO Fixed Charge  \
# 0                                   44.8              41.3
# 1                                   44.8              41.3
# 2                                   44.8              41.3
# 3                                   28.3              20.5
# 4                                   44.8              41.3
#
#    RTO Additional Weight Slab Charge  No Of Slabs
# 0                               44.8          1.0
# 1                               44.8          1.0
# 2                               44.8          2.0
# 3                               28.3          1.0
# 4                               44.8          1.0

# %%
merged_dataset_new['No Of Slabs'].unique()
# Out:
# array([1., 2., 3.])

# %% [markdown]
# ### Calculated fixed and RTO charges based on slabs

# %%
merged_dataset_new['Fixed Charge'] = merged_dataset_new['Forward Fixed Charge'] + merged_dataset_new['Forward Additional Weight Slab Charge'] * (merged_dataset_new['No Of Slabs'] - 1)

# %%
merged_dataset_new['Rto charges'] = merged_dataset_new['RTO Fixed Charge'] + merged_dataset_new['RTO Additional Weight Slab Charge'] * (merged_dataset_new['No Of Slabs'] - 1)

# %%
target_word = 'RTO'
merged_dataset_new['RTO Charge'] = merged_dataset_new['Type of Shipment'].apply(lambda x: True if target_word in x else False)

# %%
def custom_function(row):
    if row['RTO Charge']:
        return row['Rto charges']
    else:
        return 0

# %%
merged_dataset_new['Rto charges'] = merged_dataset_new.apply(custom_function,axis=1)

# %% [markdown]
# ### calculating Expected Price of X company

# %%
merged_dataset_new['Expected Price'] = merged_dataset_new['Fixed Charge'] + merged_dataset_new['Rto charges']
merged_dataset_new.head()
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0  1091117222124  2001806232            1.30             121003
# 1  1091117222194  2001806273            1.00             121003
# 2  1091117222931  2001806408            2.50             121003
# 3  1091117223244  2001806458            1.00             121003
# 4  1091117229345  2001807012            0.15             121003
#
#    Customer Pincode Zone Courier Type of Shipment  Billing Amount (Rs.)  \
# 0            507101            d  Forward charges                 135.0
# 1            486886            d  Forward charges                  90.2
# 2            532484            d  Forward charges                 224.6
# 3            143001            b  Forward charges                  61.3
# 4            515591            d  Forward charges                  45.4
#
#    Weight X Company Zone  Weight Slabs  Forward Fixed Charge  \
# 0             1.302    d           1.5                  45.4
# 1             0.615    d           1.5                  45.4
# 2             2.265    d           1.5                  45.4
# 3             0.700    b           1.0                  33.0
# 4             0.240    d           1.5                  45.4
#
#    Forward Additional Weight Slab Charge  RTO Fixed Charge  \
# 0                                   44.8              41.3
# 1                                   44.8              41.3
# 2                                   44.8              41.3
# 3                                   28.3              20.5
# 4                                   44.8              41.3
#
#    RTO Additional Weight Slab Charge  No Of Slabs  Fixed Charge  Rto charges  \
# 0                               44.8          1.0          45.4          0.0
# 1                               44.8          1.0          45.4          0.0
# 2                               44.8          2.0          90.2          0.0
# 3                               28.3          1.0          33.0          0.0
# 4                               44.8          1.0          45.4          0.0
#
#    RTO Charge  Expected Price
# 0       False            45.4
# 1       False            45.4
# 2       False            90.2
# 3       False            33.0
# 4       False            45.4

# %% [markdown]
# ### Calculated the difference between expected price and charged price

# %%
merged_dataset_new['Difference in charges'] = (merged_dataset_new['Billing Amount (Rs.)'] - merged_dataset_new['Expected Price']).round(3)
merged_dataset_new.head()
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0  1091117222124  2001806232            1.30             121003
# 1  1091117222194  2001806273            1.00             121003
# 2  1091117222931  2001806408            2.50             121003
# 3  1091117223244  2001806458            1.00             121003
# 4  1091117229345  2001807012            0.15             121003
#
#    Customer Pincode Zone Courier Type of Shipment  Billing Amount (Rs.)  \
# 0            507101            d  Forward charges                 135.0
# 1            486886            d  Forward charges                  90.2
# 2            532484            d  Forward charges                 224.6
# 3            143001            b  Forward charges                  61.3
# 4            515591            d  Forward charges                  45.4
#
#    Weight X Company Zone  ...  Forward Fixed Charge  \
# 0             1.302    d  ...                  45.4
# 1             0.615    d  ...                  45.4
# 2             2.265    d  ...                  45.4
# 3             0.700    b  ...                  33.0
# 4             0.240    d  ...                  45.4
#
#    Forward Additional Weight Slab Charge  RTO Fixed Charge  \
# 0                                   44.8              41.3
# 1                                   44.8              41.3
# 2                                   44.8              41.3
# 3                                   28.3              20.5
# 4                                   44.8              41.3
#
#    RTO Additional Weight Slab Charge  No Of Slabs  Fixed Charge  Rto charges  \
# 0                               44.8          1.0          45.4          0.0
# 1                               44.8          1.0          45.4          0.0
# 2                               44.8          2.0          90.2          0.0
# 3                               28.3          1.0          33.0          0.0
# 4                               44.8          1.0          45.4          0.0
#
#    RTO Charge  Expected Price  Difference in charges
# 0       False            45.4                   89.6
# 1       False            45.4                   44.8
# 2       False            90.2                  134.4
# 3       False            33.0                   28.3
# 4       False            45.4                    0.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Dropped all the duplicates caused due to left joins

# %%
merged_dataset_new = merged_dataset_new.drop_duplicates(ignore_index=True)

# %%
merged_dataset_new['Weight slab charged by Courier Company (KG)'] = merged_dataset_new['Weight Slabs']

# %%
merged_dataset_new.head()
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0  1091117222124  2001806232            1.30             121003
# 1  1091117222194  2001806273            1.00             121003
# 2  1091117222931  2001806408            2.50             121003
# 3  1091117223244  2001806458            1.00             121003
# 4  1091117229345  2001807012            0.15             121003
#
#    Customer Pincode Zone Courier Type of Shipment  Billing Amount (Rs.)  \
# 0            507101            d  Forward charges                 135.0
# 1            486886            d  Forward charges                  90.2
# 2            532484            d  Forward charges                 224.6
# 3            143001            b  Forward charges                  61.3
# 4            515591            d  Forward charges                  45.4
#
#    Weight X Company Zone  ...  Forward Additional Weight Slab Charge  \
# 0             1.302    d  ...                                   44.8
# 1             0.615    d  ...                                   44.8
# 2             2.265    d  ...                                   44.8
# 3             0.700    b  ...                                   28.3
# 4             0.240    d  ...                                   44.8
#
#    RTO Fixed Charge  RTO Additional Weight Slab Charge  No Of Slabs  \
# 0              41.3                               44.8          1.0
# 1              41.3                               44.8          1.0
# 2              41.3                               44.8          2.0
# 3              20.5                               28.3          1.0
# 4              41.3                               44.8          1.0
#
#    Fixed Charge  Rto charges  RTO Charge  Expected Price  \
# 0          45.4          0.0       False            45.4
# 1          45.4          0.0       False            45.4
# 2          90.2          0.0       False            90.2
# 3          33.0          0.0       False            33.0
# 4          45.4          0.0       False            45.4
#
#    Difference in charges  Weight slab charged by Courier Company (KG)
# 0                   89.6                                          1.5
# 1                   44.8                                          1.5
# 2                  134.4                                          1.5
# 3                   28.3                                          1.0
# 4                    0.0                                          1.5
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Renamed all the columns as per the requirement

# %%
merged_dataset_new.columns
# Out:
# Index(['AWB Code', 'Order ID', 'Charged Weight', 'Warehouse Pincode',
#        'Customer Pincode', 'Zone Courier', 'Type of Shipment',
#        'Billing Amount (Rs.)', 'Weight X Company', 'Zone', 'Weight Slabs',
#        'Forward Fixed Charge', 'Forward Additional Weight Slab Charge',
#        'RTO Fixed Charge', 'RTO Additional Weight Slab Charge', 'No Of Slabs',
#        'Fixed Charge', 'Rto charges', 'RTO Charge', 'Expected Price',
#        'Difference in charges'],
#       dtype='object')

# %%
merged_dataset_new.rename(columns={'Charged Weight':'Total weight as per Courier Company (KG)','Weight X Company':'Total weight as per X (KG)','Weight Slabs':'Weight slab as per X (KG)','Zone':
    'Delivery Zone as per X','Zone Courier':'Zone charged by Courier Company','Expected Price':'Expected Charge as per X (Rs.)','Billing Amount (Rs.)':'Charges Billed by Courier Company (Rs.)','Difference in charges':'Difference Between Expected Charges and Billed Charges (Rs.)'
    },inplace=True)

# %%
merged_dataset_new.rename(columns={'AWB Code':'AWB Number','Zone charged by Courier Company':'Delivery Zone charged by Courier Company'},inplace=True)

# %%
merged_dataset_new.head()
# Out:
#       AWB Number    Order ID  Total weight as per Courier Company (KG)  \
# 0  1091117222124  2001806232                                      1.30
# 1  1091117222194  2001806273                                      1.00
# 2  1091117222931  2001806408                                      2.50
# 3  1091117223244  2001806458                                      1.00
# 4  1091117229345  2001807012                                      0.15
#
#    Warehouse Pincode  Customer Pincode  \
# 0             121003            507101
# 1             121003            486886
# 2             121003            532484
# 3             121003            143001
# 4             121003            515591
#
#   Delivery Zone charged by Courier Company Type of Shipment  \
# 0                                        d  Forward charges
# 1                                        d  Forward charges
# 2                                        d  Forward charges
# 3                                        b  Forward charges
# 4                                        d  Forward charges
#
#    Charges Billed by Courier Company (Rs.)  Total weight as per X (KG)  \
# 0                                    135.0                       1.302
# 1                                     90.2                       0.615
# 2                                    224.6                       2.265
# 3                                     61.3                       0.700
# 4                                     45.4                       0.240
#
#   Delivery Zone as per X  ...  Forward Additional Weight Slab Charge  \
# 0                      d  ...                                   44.8
# 1                      d  ...                                   44.8
# 2                      d  ...                                   44.8
# 3                      b  ...                                   28.3
# 4                      d  ...                                   44.8
#
#    RTO Fixed Charge  RTO Additional Weight Slab Charge  No Of Slabs  \
# 0              41.3                               44.8          1.0
# 1              41.3                               44.8          1.0
# 2              41.3                               44.8          2.0
# 3              20.5                               28.3          1.0
# 4              41.3                               44.8          1.0
#
#    Fixed Charge  Rto charges  RTO Charge  Expected Charge as per X (Rs.)  \
# 0          45.4          0.0       False                            45.4
# 1          45.4          0.0       False                            45.4
# 2          90.2          0.0       False                            90.2
# 3          33.0          0.0       False                            33.0
# 4          45.4          0.0       False                            45.4
#
#    Difference Between Expected Charges and Billed Charges (Rs.)  \
# 0                                               89.6
# 1                                               44.8
# 2                                              134.4
# 3                                               28.3
# 4                                                0.0
#
#    Weight slab charged by Courier Company (KG)
# 0                                          1.5
# 1                                          1.5
# 2                                          1.5
# 3                                          1.0
# 4                                          1.5
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Created a new dataset as per result csv and exported it excel file

# %%
df_result = merged_dataset_new[['Order ID','AWB Number','Total weight as per X (KG)','Weight slab as per X (KG)','Total weight as per Courier Company (KG)','Weight slab charged by Courier Company (KG)','Delivery Zone as per X','Delivery Zone charged by Courier Company','Expected Charge as per X (Rs.)','Charges Billed by Courier Company (Rs.)','Difference Between Expected Charges and Billed Charges (Rs.)']]

# %%
df_result.head()
# Out:
#      Order ID     AWB Number  Total weight as per X (KG)  \
# 0  2001806232  1091117222124                       1.302
# 1  2001806273  1091117222194                       0.615
# 2  2001806408  1091117222931                       2.265
# 3  2001806458  1091117223244                       0.700
# 4  2001807012  1091117229345                       0.240
#
#    Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                        1.5                                      1.30
# 1                        1.5                                      1.00
# 2                        1.5                                      2.50
# 3                        1.0                                      1.00
# 4                        1.5                                      0.15
#
#    Weight slab charged by Courier Company (KG) Delivery Zone as per X  \
# 0                                          1.5                      d
# 1                                          1.5                      d
# 2                                          1.5                      d
# 3                                          1.0                      b
# 4                                          1.5                      d
#
#   Delivery Zone charged by Courier Company  Expected Charge as per X (Rs.)  \
# 0                                        d                            45.4
# 1                                        d                            45.4
# 2                                        d                            90.2
# 3                                        b                            33.0
# 4                                        d                            45.4
#
#    Charges Billed by Courier Company (Rs.)  \
# 0                                    135.0
# 1                                     90.2
# 2                                    224.6
# 3                                     61.3
# 4                                     45.4
#
#    Difference Between Expected Charges and Billed Charges (Rs.)
# 0                                               89.6
# 1                                               44.8
# 2                                              134.4
# 3                                               28.3
# 4                                                0.0

# %%
df_result.to_excel('Result.xlsx', index=False)

# %% [markdown]
# ## Calculated the count and total of difference based on correctly Charged, Undercharged, Overcharged

# %%
def custom_function_new(row):
    if row['Difference Between Expected Charges and Billed Charges (Rs.)'] > 0:
        return 1
    elif row['Difference Between Expected Charges and Billed Charges (Rs.)'] == 0:
        return 0
    else:
        return -1

# %%
merged_dataset_new['Profit'] = merged_dataset_new.apply(custom_function_new,axis=1)

# %%
merged_dataset_new.groupby('Profit').size()
# Out:
# Profit
# -1      2
#  0      8
#  1    114
# dtype: int64

# %%
merged_dataset_new.groupby('Profit').sum()
# Out:
#              AWB Number      Order ID  \
# Profit
# -1        2182242197518    4003630727
#  0        8728938630502   16014459932
#  1      124387478881758  228206442321
#
#         Total weight as per Courier Company (KG)  Warehouse Pincode  \
# Profit
# -1                                          0.80             242006
#  0                                          3.15             968024
#  1                                        114.60           13794342
#
#         Customer Pincode           Delivery Zone charged by Courier Company  \
# Profit
# -1                347313                                                 bb
#  0               3815942                                           dddddbeb
#  1              41157266  dddbbbbdbdddbdbdbddedbddddbddbddddbdbbddddbbdd...
#
#                                          Type of Shipment  \
# Profit
# -1                         Forward chargesForward charges
#  0      Forward chargesForward chargesForward chargesF...
#  1      Forward chargesForward chargesForward chargesF...
#
#         Charges Billed by Courier Company (Rs.)  Total weight as per X (KG)  \
# Profit
# -1                                         66.0                       0.959
#  0                                        428.6                       3.356
#  1                                      13153.6                      84.161
#
#                                    Delivery Zone as per X  ...  \
# Profit                                                     ...
# -1                                                     ee  ...
#  0                                               dddddbeb  ...
#  1      dddbbbbdbdddbdbdbddedbddddbddbddddbdbbddddbbdd...  ...
#
#         Forward Additional Weight Slab Charge  RTO Fixed Charge  \
# Profit
# -1                                      111.0             101.4
#  0                                      336.1             298.2
#  1                                     3879.5            3144.2
#
#         RTO Additional Weight Slab Charge  No Of Slabs  Fixed Charge  \
# Profit
# -1                                  111.0          2.0         113.2
#  0                                  336.1          9.0         377.9
#  1                                 3879.5        132.0        4901.2
#
#         Rto charges  RTO Charge  Expected Charge as per X (Rs.)  \
# Profit
# -1              0.0           0                           113.2
#  0             50.7           1                           428.6
#  1            556.7          14                          5457.9
#
#         Difference Between Expected Charges and Billed Charges (Rs.)  \
# Profit
# -1                                                  -47.2
#  0                                                    0.0
#  1                                                 7695.7
#
#         Weight slab charged by Courier Company (KG)
# Profit
# -1                                              4.0
#  0                                             11.5
#  1                                            134.5
#
# [3 rows x 22 columns]
